# %% [markdown]
# <a href="https://colab.research.google.com/github/ralizaga/Simulac_system/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Lista de datos proporcionados
datos = [
0.6435,0.0168,0.3553,0.1242,0.4006,0.2944,0.1438,0.7612,0.4776,0.6031,
0.9849,0.1133,0.3846,0.2806,0.2376,0.5657,0.7546,0.8071,0.1012,0.9288,
0.9152,0.5673,0.3063,0.9285,0.3883,0.4072,0.0982,0.5163,0.0935,0.1209,
0.8327,0.5013,0.1319,0.4257,0.7998,0.6198,0.4946,0.5810,0.4389,0.5537,
0.2803,0.0330,0.3769,0.5007,0.9111,0.6809,0.1837,0.6720,0.7195,0.1219,
0.1730,0.9814,0.3809,0.9997,0.5554,0.7154,0.5438,0.6020,0.7738,0.9657,
0.9002,0.7602,0.5290,0.2072,0.6080,0.8810,0.6598,0.0120,0.8939,0.9734,
0.1853,0.1865,0.8586,0.0580,0.6724,0.3028,0.6460,0.4502,0.5225,0.9955,
0.3499,0.5518,0.6225,0.5460,0.0332,0.5950,0.8039,0.4228,0.1220,0.2281,
0.7368,0.1064,0.5425,0.3910,0.9451,0.3131,0.1599,0.2734,0.8265,0.1084
]

# Convertir a array de numpy
datos = np.array(datos)

# Definir ventana para promedio móvil (ejemplo: 5)
ventana = 5
promedios_moviles = np.convolve(datos, np.ones(ventana)/ventana, mode='valid')

# Graficar
plt.figure(figsize=(10,6))
plt.plot(range(len(datos)), datos, label='Datos originales', alpha=0.5)
plt.plot(range(ventana-1, len(datos)), promedios_moviles, label=f'Promedio móvil ({ventana})', color='red')
plt.axhline(np.mean(promedios_moviles), color='green', linestyle='--', label='Valor estable ~0.55')
plt.title('Promedio móvil y estado estable')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.legend()
plt.grid(True)
plt.show()

# Determinar inicio del estado estable
media = np.mean(promedios_moviles)
desviacion = np.std(promedios_moviles)
umbral_inferior = media - desviacion*0.1
umbral_superior = media + desviacion*0.1

inicio_estable = None
for i, val in enumerate(promedios_moviles):
    if umbral_inferior <= val <= umbral_superior:
        inicio_estable = i + ventana - 1
        break

print(f"El estado estable comienza aproximadamente en el índice {inicio_estable}, con valor cercano a {media:.3f}")
# Out:
# El estado estable comienza aproximadamente en el índice 12, con valor cercano a 0.505
