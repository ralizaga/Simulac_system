# %% [markdown]
# <a href="https://colab.research.google.com/github/ralizaga/Simulac_system/blob/Ejercicio01/Bank_clients01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simpy
import simpy
import random

# Proceso de atención de un cliente
def cliente(env, nombre, cajero):
    print(f"{nombre} llega al banco en el minuto {env.now}")
    with cajero.request() as req:
        yield req
        print(f"{nombre} comienza a ser atendido en el minuto {env.now}")
        tiempo_atencion = random.randint(3, 7)  # tiempo de servicio
        yield env.timeout(tiempo_atencion)
        print(f"{nombre} termina en el minuto {env.now}")

# Generador de clientes
def generador_clientes(env, cajero):
    i = 0
    while True:
        yield env.timeout(random.randint(2, 5))  # tiempo entre llegadas
        i += 1
        env.process(cliente(env, f"Cliente {i}", cajero))

# Configuración de la simulación
env = simpy.Environment()
cajero = simpy.Resource(env, capacity=1)  # solo un cajero
env.process(generador_clientes(env, cajero))

# Ejecutar simulación por 30 minutos
env.run(until=30)
# Out:
# Requirement already satisfied: simpy in /usr/local/lib/python3.12/dist-packages (4.1.1)
# Cliente 1 llega al banco en el minuto 2
# Cliente 1 comienza a ser atendido en el minuto 2
# Cliente 2 llega al banco en el minuto 6
# Cliente 1 termina en el minuto 9
# Cliente 3 llega al banco en el minuto 9
# Cliente 2 comienza a ser atendido en el minuto 9
# Cliente 4 llega al banco en el minuto 12
# Cliente 2 termina en el minuto 15
# Cliente 5 llega al banco en el minuto 15
# Cliente 3 comienza a ser atendido en el minuto 15
# Cliente 6 llega al banco en el minuto 18
# Cliente 3 termina en el minuto 19
# Cliente 4 comienza a ser atendido en el minuto 19
# Cliente 7 llega al banco en el minuto 21
# Cliente 8 llega al banco en el minuto 25
# Cliente 4 termina en el minuto 26
# Cliente 5 comienza a ser atendido en el minuto 26
# Cliente 9 llega al banco en el minuto 27
# Cliente 5 termina en el minuto 29
# Cliente 6 comienza a ser atendido en el minuto 29
