# %% [markdown]
# <a href="https://colab.research.google.com/github/ralizaga/Simulac_system/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simpy
import simpy
import random

# Parámetros del sistema
TIEMPO_MOLDEO = 30        # segundos (media)
TIEMPO_ENFRIAMIENTO = 60  # segundos (constante)
TIEMPO_INSPECCION = 45    # segundos (media)
TAMANO_LOTE_EMPAQUE = 100 # botellas por lote
NUM_MAQUINAS_MOLDEO = 2
NUM_INSPECTORES = 1

# Proceso de producción de una botella
def producir_botella(env, id_botella, moldeo, inspeccion, empaque):
    # Moldeo
    with moldeo.request() as req:
        yield req
        tiempo = random.normalvariate(TIEMPO_MOLDEO, 5)
        yield env.timeout(tiempo)
        print(f"Botella {id_botella} moldeada en {env.now:.1f}")

    # Enfriamiento
    yield env.timeout(TIEMPO_ENFRIAMIENTO)
    print(f"Botella {id_botella} enfriada en {env.now:.1f}")

    # Inspección
    with inspeccion.request() as req:
        yield req
        tiempo = random.expovariate(1.0/TIEMPO_INSPECCION)
        yield env.timeout(tiempo)
        print(f"Botella {id_botella} inspeccionada en {env.now:.1f}")

    # Empaque (se acumulan hasta formar un lote)
    empaque.append(id_botella)
    if len(empaque) >= TAMANO_LOTE_EMPAQUE:
        print(f"Lote de {TAMANO_LOTE_EMPAQUE} botellas empacado en {env.now:.1f}")
        empaque.clear()

# Generador de llegadas de botellas
def llegada_botellas(env, moldeo, inspeccion, empaque):
    id_botella = 0
    while True:
        yield env.timeout(random.expovariate(1/20))  # llegada cada ~20 seg
        id_botella += 1
        env.process(producir_botella(env, id_botella, moldeo, inspeccion, empaque))

# Configuración del entorno
env = simpy.Environment()
moldeo = simpy.Resource(env, NUM_MAQUINAS_MOLDEO)
inspeccion = simpy.Resource(env, NUM_INSPECTORES)
empaque = []

# Iniciar simulación
env.process(llegada_botellas(env, moldeo, inspeccion, empaque))
env.run(until=500)  # simular 500 segundos
# Out:
# Collecting simpy
#   Downloading simpy-4.1.2-py3-none-any.whl.metadata (6.2 kB)
# Downloading simpy-4.1.2-py3-none-any.whl (27 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.1.2
# Botella 2 moldeada en 29.9
# Botella 1 moldeada en 30.8
# Botella 3 moldeada en 56.0
# Botella 2 enfriada en 89.9
# Botella 1 enfriada en 90.8
# Botella 2 inspeccionada en 103.2
# Botella 4 moldeada en 109.5
# Botella 1 inspeccionada en 110.8
# Botella 3 enfriada en 116.0
# Botella 3 inspeccionada en 124.8
# Botella 5 moldeada en 126.0
# Botella 6 moldeada en 143.8
# Botella 7 moldeada en 149.4
# Botella 4 enfriada en 169.5
# Botella 8 moldeada en 174.3
# Botella 4 inspeccionada en 177.7
# Botella 5 enfriada en 186.0
# Botella 9 moldeada en 190.3
# Botella 6 enfriada en 203.8
# Botella 7 enfriada en 209.4
# Botella 10 moldeada en 212.0
# Botella 5 inspeccionada en 219.3
# Botella 11 moldeada en 223.4
# Botella 8 enfriada en 234.3
# Botella 12 moldeada en 242.8
# Botella 9 enfriada en 250.3
# Botella 13 moldeada en 250.5
# Botella 10 enfriada en 272.0
# Botella 14 moldeada en 274.1
# Botella 15 moldeada en 276.9
# Botella 11 enfriada en 283.4
# Botella 12 enfriada en 302.8
# Botella 13 enfriada en 310.5
# Botella 17 moldeada en 318.8
# Botella 16 moldeada en 321.5
# Botella 14 enfriada en 334.1
# Botella 15 enfriada en 336.9
# Botella 18 moldeada en 348.0
# Botella 6 inspeccionada en 349.2
# Botella 19 moldeada en 355.5
# Botella 7 inspeccionada en 373.1
# Botella 17 enfriada en 378.8
# Botella 21 moldeada en 379.8
# Botella 16 enfriada en 381.5
# Botella 20 moldeada en 388.8
# Botella 8 inspeccionada en 391.2
# Botella 18 enfriada en 408.0
# Botella 19 enfriada en 415.5
# Botella 22 moldeada en 418.2
# Botella 23 moldeada en 418.4
# Botella 21 enfriada en 439.8
# Botella 24 moldeada en 448.2
# Botella 20 enfriada en 448.8
# Botella 9 inspeccionada en 449.6
# Botella 25 moldeada en 449.8
# Botella 10 inspeccionada en 458.7
# Botella 27 moldeada en 475.2
# Botella 22 enfriada en 478.2
# Botella 23 enfriada en 478.4
# Botella 26 moldeada en 480.7
# Botella 11 inspeccionada en 488.2
